# %% [markdown]
# <a href="https://colab.research.google.com/github/Alishahzad1903/PandID/blob/main/PandID.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install kaggle

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp /content/drive/MyDrive/kaggle.json /content/Kaggle

# %%
# !kaggle datasets download -d hristohristov21/pid-symbols
# Out:
# Dataset URL: https://www.kaggle.com/datasets/hristohristov21/pid-symbols
# License(s): other
# ...
# 100% 1.41G/1.41G [01:22<00:00, 18.1MB/s]
# 100% 1.41G/1.41G [01:22<00:00, 18.4MB/s]

# %%
# !unzip pid-symbols.zip -d ./pid-symbols
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: ./pid-symbols/labels (2)/475_3200_1920.txt
#   inflating: ./pid-symbols/labels (2)/475_3200_2560.txt
#   inflating: ./pid-symbols/labels (2)/475_3200_3200.txt
#   inflating: ./pid-symbols/labels (2)/475_3200_3840.txt
#   inflating: ./pid-symbols/labels (2)/475_3200_4480.txt
#   inflating: ./pid-symbols/labels (2)/475_3200_5120.txt
#   inflating: ./pid-symbols/labels (2)/475_3200_5760.txt
#   inflating: ./pid-symbols/labels (2)/475_3200_640.txt
#   inflating: ./pid-symbols/labels (2)/475_640_0.txt
#   inflating: ./pid-symbols/labels (2)/475_640_1280.txt
#   inflating: ./pid-symbols/labels (2)/475_640_1920.txt
#   inflating: ./pid-symbols/labels (2)/475_640_2560.txt
#   inflating: ./pid-symbols/labels (2)/475_640_3200.txt
#   inflating: ./pid-symbols/labels (2)/475_640_3840.txt
#   inflating: ./pid-symbols/labels (2)/475_640_4480.txt
#   inflating: ./pid-symbols/labels (2)/475_640_5120.txt
# ...

# %%
base_dir = 'dataset'

# %%
import os
import shutil

# %%
images_dir = os.path.join(base_dir, 'images')
labels_dir = os.path.join(base_dir, 'labels')

# %%
train_images_dir = os.path.join(images_dir, 'train')
val_images_dir = os.path.join(images_dir, 'val')
train_labels_dir = os.path.join(labels_dir, 'train')
val_labels_dir = os.path.join(labels_dir, 'val')

# %%
os.makedirs(train_images_dir, exist_ok=True)
os.makedirs(val_images_dir, exist_ok=True)
os.makedirs(train_labels_dir, exist_ok=True)
os.makedirs(val_labels_dir, exist_ok=True)

# %%
def move_files(file_list, source_dir,labels_dir, dest_image_dir, dest_label_dir):
    with open(file_list, 'r') as f:
        files = f.read().splitlines()

    for file in files:
        image_path = os.path.join(source_dir, file)
        if os.path.exists(image_path):
            shutil.move(image_path, dest_image_dir)

        label_path = os.path.join(labels_dir, os.path.splitext(file)[0] + '.txt')
        if os.path.exists(label_path):
            shutil.move(label_path, dest_label_dir)

# %%
move_files("/content/pid-symbols/train (2).txt","/content/pid-symbols/images (3)" ,"/content/pid-symbols/labels (2)", train_images_dir, train_labels_dir)
#move_files(os.path.join(base_dir, 'val.txt'), images_dir, val_images_dir, val_labels_dir)
